# %%
from SRIL_utils.tmux_utils import tmux_session,get_session_list,kill_session

# %%
from pathlib import Path 
import datetime

# %%
get_session_list()
# Out:
# [Session($34 Duck_tape_adj_270),
#  Session($24 diff_psf_zvi2_8bit),
#  Session($25 diff_psf_zvi2_8bit_200ep),
#  Session($28 diff_psf_zvi2_8bit_200ep_try2),
#  Session($4 tb)]

# %%
base_root_dir = '/home/nadav/dev/PhoColens_Runs/SVDeconv'

dataset_name='diff_psf_zvi2_8bit'
res_dir =f'/mnt/extra/experiments/lensless/results/experiments{dataset_name}'
base_image_dir=f'/mnt/extra/traning_datasets/lenless_simulated/{dataset_name}'
train_image_dir = f'{base_image_dir}/train'
test_image_dir = f'{base_image_dir}/test'
psf_file_name= "psf.tiff"
timestamp =  datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
timestamp
# Out:
# '20260616-210829'

# %%
base_root_dir = '/home/nadav/dev/PhoColens_Runs/SVDeconv'

dataset_name='Duck_tape_adj_270/'
res_dir =f'/mnt/extra/experiments/lensless/results/experiments{dataset_name}'
base_image_dir=f'/mnt/extra/traning_datasets/lenless_simulated/{dataset_name}'
train_image_dir = f'{base_image_dir}/train'
test_image_dir = f'{base_image_dir}/test'
psf_file_name= "psf.npy"
timestamp =  datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
timestamp
# Out:
# '20260616-210829'

# %%
Path(base_image_dir).exists()
# Out:
# True

# %%
train_py_cmd = [
    'python train_diff.py',
    'with',
    f'image_dir={train_image_dir}',
    f'psf_file_name={psf_file_name}',
    f'timestamp={timestamp}'
]
train_py_cmd = ' '.join(train_py_cmd)

# %%
val_py_cmd = [
    'python val_diff.py',
    'with',
    f'image_dir={train_image_dir}',
    f'psf_file_name={psf_file_name}',
    f'test_set_path={test_image_dir}',
    "eval_on=val",
    f'ckpt_dir={base_root_dir}/runs/diffusercam/fft-diffusercam/{timestamp}/ckpts/',
    f'output_dir={res_dir}',
]
val_py_cmd = ' '.join(val_py_cmd)

# %%
train_py_cmd,val_py_cmd
# Out:
# ('python train_diff.py with image_dir=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/train timestamp=20260616-210829',
#  'python val_diff.py with image_dir=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/train test_set_path=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/test eval_on=val ckpt_dir=/home/nadav/dev/PhoColens_Runs/SVDeconv/runs/diffusercam/fft-diffusercam/20260616-210829/ckpts/ output_dir=/mnt/extra/experiments/lensless/results/experimentsdiff_psf_zvi2_8bit')

# %%
ins_list = [
    'venv pho',
    f'cd {base_root_dir}',
    f'{train_py_cmd}',
    f'{val_py_cmd}'
   
]

# %%
ins_list
# Out:
# ['venv pho',
#  'cd /home/nadav/dev/PhoColens_Runs/SVDeconv',
#  'python train_diff.py with image_dir=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/train timestamp=20260616-210829',
#  'python val_diff.py with image_dir=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/train test_set_path=/mnt/extra/traning_datasets/lenless_simulated/diff_psf_zvi2_8bit/test eval_on=val ckpt_dir=/home/nadav/dev/PhoColens_Runs/SVDeconv/runs/diffusercam/fft-diffusercam/20260616-210829/ckpts/ output_dir=/mnt/extra/experiments/lensless/results/experimentsdiff_psf_zvi2_8bit']

# %%
kill_session(not_to_kill='tb')
# Out:
# before kill sessions=[Session($23 diff_psf_zvi2_8bit), Session($4 tb)]
# after kill sessions=[Session($4 tb)]

# %%
tmux_session(ins_list=ins_list,session_name=dataset_name+'_200ep_try2')
# Out:
# tmux attach -t "diff_psf_zvi2_8bit_200ep_try2"
# 'diff_psf_zvi2_8bit_200ep_try2'

# %%
2**16
# Out:
# 65536
